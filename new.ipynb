# %% [markdown]
# <a href="https://colab.research.google.com/github/anaghazachariah/images/blob/main/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd 'drive/My Drive/images'
# Out:
# /content/drive/My Drive/images

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("ww.jpg",0)#if we give 1 as second arguement we will get color image.if we give 0 we will get black and white
cv2_imshow(img)
print(img.shape)#when the image is black and white the shape is a 2d array.But when image has color the shape will be in 3d.Third value(3) says that we have 3 2d arrays.one for red,one for blue and one for green
# Out:
# <PIL.Image.Image image mode=L size=332x332 at 0x7F3FA4148890>
# (332, 332)

# %%
# For edge detection
#img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)# canny accepts only black and white..if imgage is already black and white no need of this line
edges = cv2.Canny(img, 100, 100)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=332x332 at 0x7F3FA4148F10>

# %%
from skimage import io
from matplotlib import pyplot as plt
my_image=io.imread('ww.jpg')#reading image as  array
print(my_image)
plt.imshow(my_image)#converting numpy array back to image
print(my_image.min(),my_image.max())#print minimum and maximum value in array.for int array it will be 0 and 255
# Out:
# [[[186  47   6]
#   [186  47   6]
#   [186  47   6]
#   ...
#   [181  48   3]
#   [180  47   2]
#   [179  46   1]]
#
#  [[186  47   6]
#   [187  48   7]
#   [188  49   8]
#   ...
#   [183  50   5]
#   [182  49   4]
#   [181  48   3]]
#
#  [[186  47   6]
#   [188  49   8]
#   [190  51  10]
#   ...
#   [186  53   8]
#   [185  52   7]
#   [183  50   5]]
#
#  ...
#
#  [[174  51   7]
#   [195  73  24]
#   [206  85  32]
#   ...
#   [226 176 153]
#   [197 128  95]
#   [184 101  61]]
#
#  [[183  63  13]
#   [200  80  28]
#   [208  89  33]
#   ...
#   [219 164 134]
#   [192 117  78]
#   [181  90  43]]
#
#  [[187  70  17]
#   [200  83  29]
#   [205  91  31]
#   ...
#   [213 154 122]
#   [188 109  66]
#   [180  84  34]]]
# 0 255

# %%
from skimage import img_as_float#img_as_int :converts array to int, img_as_uint converts array to uint,img_as_ubyte :convert image to unit, 
float_img=img_as_float(my_image)#convert integer  array to float  array
plt.imshow(float_img)
print(float_img.min(),float_img.max())#print minimum and maximum value in array.for float array it will be 0 and 1
# Out:
# 0.0 1.0
